# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"C:\Users\Juhi\IITB\sem2\MIC\MIC_project\bcn20000_metadata_2026-04-14.csv")

# %%
df.columns
# Out:
# Index(['isic_id', 'attribution', 'copyright_license', 'age_approx',
#        'anatom_site_1', 'anatom_site_2', 'anatom_site_general',
#        'anatom_site_special', 'concomitant_biopsy', 'diagnosis_1',
#        'diagnosis_2', 'diagnosis_3', 'diagnosis_confirm_type', 'image_type',
#        'lesion_id', 'melanocytic', 'sex'],
#       dtype='str')

# %%
df.head()
# Out:
#         isic_id                   attribution copyright_license  age_approx  \
# 0  ISIC_0053453  Hospital Clínic de Barcelona          CC-BY-NC        60.0
# 1  ISIC_0053454  Hospital Clínic de Barcelona          CC-BY-NC        55.0
# 2  ISIC_0053455  Hospital Clínic de Barcelona          CC-BY-NC        50.0
# 3  ISIC_0053456  Hospital Clínic de Barcelona          CC-BY-NC        50.0
# 4  ISIC_0053457  Hospital Clínic de Barcelona          CC-BY-NC        85.0
#
#      anatom_site_1   anatom_site_2 anatom_site_general anatom_site_special  \
# 0            Trunk  Anterior trunk      anterior torso                 NaN
# 1            Trunk  Anterior trunk      anterior torso                 NaN
# 2  Lower extremity             NaN     lower extremity                 NaN
# 3            Trunk  Anterior trunk      anterior torso                 NaN
# 4    Head and neck             NaN           head/neck                 NaN
#
#    concomitant_biopsy diagnosis_1  \
# ...

# %%
df.diagnosis_3.value_counts()
# Out:
# diagnosis_3
# Nevus                           5647
# Melanoma, NOS                   4003
# Basal cell carcinoma            3676
# Seborrheic keratosis            1268
# Solar or actinic keratosis      1088
# Melanoma metastasis              633
# Squamous cell carcinoma, NOS     559
# Scar                             314
# Solar lentigo                    283
# Dermatofibroma                   168
# Name: count, dtype: int64

# %%
df.diagnosis_2.value_counts()
# Out:
# diagnosis_2
# Benign melanocytic proliferations                           5647
# Malignant melanocytic proliferations (Melanoma)             4636
# Malignant adnexal epithelial proliferations - Follicular    3676
# Benign epidermal proliferations                             1551
# Indeterminate epidermal proliferations                      1088
# Malignant epidermal proliferations                           559
# Benign soft tissue proliferations - Fibro-histiocytic        482
# Benign soft tissue proliferations - Vascular                 151
# Name: count, dtype: int64

# %%
# Exactly the same
# Nevus -> nv
# Basal cell carcinoma -> bcc
# Dermatofibroma -> df
# Solar or actinic keratosis -> akiec

# Selected mapping
# Melanoma, NOS -> mel
# Seborrheic keratosis -> bkl
# Get vasc from diagnostic_2

# Ignore
# Squamous cell carcinoma
# Scar

# %%
df.loc[
    df["diagnosis_2"] == "Benign soft tissue proliferations - Vascular",
    "diagnosis_3"
] = "Benign soft tissue proliferations - Vascular (diagnosis_2)"

# %%
df.diagnosis_3.value_counts()
# Out:
# diagnosis_3
# Nevus                                                         5647
# Melanoma, NOS                                                 4003
# Basal cell carcinoma                                          3676
# Seborrheic keratosis                                          1268
# Solar or actinic keratosis                                    1088
# Melanoma metastasis                                            633
# Squamous cell carcinoma, NOS                                   559
# Scar                                                           314
# Solar lentigo                                                  283
# Dermatofibroma                                                 168
# Benign soft tissue proliferations - Vascular (diagnosis_2)     151
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18946 entries, 0 to 18945
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   isic_id                 18946 non-null  str
#  1   attribution             18946 non-null  str
#  2   copyright_license       18946 non-null  str
#  3   age_approx              18825 non-null  float64
#  4   anatom_site_1           17880 non-null  str
#  5   anatom_site_2           7369 non-null   str
#  6   anatom_site_general     18649 non-null  str
#  7   anatom_site_special     769 non-null    str
#  8   concomitant_biopsy      18946 non-null  bool
#  9   diagnosis_1             17790 non-null  str
#  10  diagnosis_2             17790 non-null  str
#  11  diagnosis_3             17790 non-null  str
#  12  diagnosis_confirm_type  15440 non-null  str
#  13  image_type              18946 non-null  str
#  14  lesion_id               18946 non-null  str
# ...

# %%
df.diagnosis_3.value_counts()
# Out:
# diagnosis_3
# Nevus                                                         5647
# Melanoma, NOS                                                 4003
# Basal cell carcinoma                                          3676
# Seborrheic keratosis                                          1268
# Solar or actinic keratosis                                    1088
# Melanoma metastasis                                            633
# Squamous cell carcinoma, NOS                                   559
# Scar                                                           314
# Solar lentigo                                                  283
# Dermatofibroma                                                 168
# Benign soft tissue proliferations - Vascular (diagnosis_2)     151
# Name: count, dtype: int64

# %%
df.describe(include="all")
# Out:
#              isic_id                   attribution copyright_license  \
# count          18946                         18946             18946
# unique         18946                             1                 1
# top     ISIC_0053453  Hospital Clínic de Barcelona          CC-BY-NC
# freq               1                         18946             18946
# mean             NaN                           NaN               NaN
# std              NaN                           NaN               NaN
# min              NaN                           NaN               NaN
# 25%              NaN                           NaN               NaN
# 50%              NaN                           NaN               NaN
# 75%              NaN                           NaN               NaN
# max              NaN                           NaN               NaN
#
#          age_approx anatom_site_1   anatom_site_2 anatom_site_general  \
# ...

# %%
df.shape
# Out:
# (18946, 17)

# %%
# number of lesions are less and images are more
df.lesion_id.value_counts()
# Out:
# lesion_id
# IL_5161836    31
# IL_2969638    31
# IL_4702939    27
# IL_4163485    27
# IL_9292662    26
#               ..
# IL_5092777     1
# IL_1247431     1
# IL_0449110     1
# IL_5363787     1
# IL_3588629     1
# Name: count, Length: 5440, dtype: int64

# %%
df_count = df.groupby('lesion_id').count()
# number of times a lesion appears
df_count
# Out:
#             isic_id  attribution  copyright_license  age_approx  \
# lesion_id
# IL_0000277        1            1                  1           1
# IL_0001676        2            2                  2           2
# IL_0002125        2            2                  2           2
# IL_0014308        2            2                  2           2
# IL_0016184        3            3                  3           3
# ...             ...          ...                ...         ...
# IL_9991727        1            1                  1           1
# IL_9993052        4            4                  4           4
# IL_9996337        5            5                  5           5
# IL_9998632        1            1                  1           1
# IL_9999026        6            6                  6           6
#
#             anatom_site_1  anatom_site_2  anatom_site_general  \
# lesion_id
# IL_0000277              1              1                    1
# ...

# %%
# taking only those lesions having single count
df_count = df_count[df_count['diagnosis_3'] == 1]
df_count.reset_index(inplace=True)

# %%
df_count
# Out:
#       lesion_id  isic_id  attribution  copyright_license  age_approx  \
# 0    IL_0000277        1            1                  1           1
# 1    IL_0059975        1            1                  1           1
# 2    IL_0069872        1            1                  1           1
# 3    IL_0085039        1            1                  1           1
# 4    IL_0121933        1            1                  1           1
# ..          ...      ...          ...                ...         ...
# 741  IL_9985024        1            1                  1           1
# 742  IL_9989548        1            1                  1           1
# 743  IL_9989891        1            1                  1           1
# 744  IL_9991727        1            1                  1           1
# 745  IL_9998632        1            1                  1           1
#
#      anatom_site_1  anatom_site_2  anatom_site_general  anatom_site_special  \
# ...

# %% [markdown]
# ### Computing train test split

# %%
train,test = train_test_split(df["lesion_id"].unique(),random_state=42)

# %%
train
# Out:
# <StringArray>
# ['IL_5733393', 'IL_3096654', 'IL_1876389', 'IL_9367665', 'IL_9105360',
#  'IL_5629866', 'IL_9665672', 'IL_3629164', 'IL_6096874', 'IL_7334395',
#  ...
#  'IL_1955343', 'IL_2493303', 'IL_8785558', 'IL_5414314', 'IL_6459311',
#  'IL_1127006', 'IL_2965493', 'IL_0349863', 'IL_2299905', 'IL_9924333']
# Length: 4080, dtype: str

# %%
test
# Out:
# <StringArray>
# ['IL_2459455', 'IL_4204830', 'IL_5727785', 'IL_2765340', 'IL_4713718',
#  'IL_6140541', 'IL_6010077', 'IL_3560021', 'IL_8651031', 'IL_7568959',
#  ...
#  'IL_6023413', 'IL_4391327', 'IL_2396987', 'IL_9311888', 'IL_9570955',
#  'IL_7260792', 'IL_4952338', 'IL_2857034', 'IL_0206046', 'IL_9317487']
# Length: 1360, dtype: str

# %%
test_df = df[df['lesion_id'].isin(set(test))]

# %%
test_df.diagnosis_3.value_counts()
# Out:
# diagnosis_3
# Nevus                                                         1433
# Melanoma, NOS                                                  981
# Basal cell carcinoma                                           888
# Solar or actinic keratosis                                     304
# Seborrheic keratosis                                           292
# Melanoma metastasis                                            178
# Squamous cell carcinoma, NOS                                   140
# Solar lentigo                                                   80
# Dermatofibroma                                                  68
# Scar                                                            66
# Benign soft tissue proliferations - Vascular (diagnosis_2)      43
# Name: count, dtype: int64

# %%
train_df = df[df["lesion_id"].isin(set(train))]

# %%
train_df.shape,test_df.shape
# Out:
# ((14168, 17), (4778, 17))

# %%
train_df.diagnosis_3.value_counts()
# Out:
# diagnosis_3
# Nevus                                                         4214
# Melanoma, NOS                                                 3022
# Basal cell carcinoma                                          2788
# Seborrheic keratosis                                           976
# Solar or actinic keratosis                                     784
# Melanoma metastasis                                            455
# Squamous cell carcinoma, NOS                                   419
# Scar                                                           248
# Solar lentigo                                                  203
# Benign soft tissue proliferations - Vascular (diagnosis_2)     108
# Dermatofibroma                                                 100
# Name: count, dtype: int64

# %%
df.diagnosis_3.value_counts()
# Out:
# diagnosis_3
# Nevus                                                         5647
# Melanoma, NOS                                                 4003
# Basal cell carcinoma                                          3676
# Seborrheic keratosis                                          1268
# Solar or actinic keratosis                                    1088
# Melanoma metastasis                                            633
# Squamous cell carcinoma, NOS                                   559
# Scar                                                           314
# Solar lentigo                                                  283
# Dermatofibroma                                                 168
# Benign soft tissue proliferations - Vascular (diagnosis_2)     151
# Name: count, dtype: int64

# %%
mapping = {
    # direct
    "Nevus": "nv",
    "Basal cell carcinoma": "bcc",
    "Dermatofibroma": "df",
    "Solar or actinic keratosis": "akiec",

    # selected
    "Melanoma, NOS": "mel",
    "Seborrheic keratosis": "bkl",
    "Benign soft tissue proliferations - Vascular (diagnosis_2)": "vasc"
}

# %%
train_df["dx"] = train_df["diagnosis_3"].map(mapping)

# %%
test_df["dx"] = test_df["diagnosis_3"].map(mapping)

# %%
train_df = train_df.copy()

# %%
train_df = train_df.dropna(subset=["dx"])

# %%
test_df = test_df.dropna(subset=["dx"])

# %%
train_df
# Out:
#             isic_id                   attribution copyright_license  \
# 0      ISIC_0053453  Hospital Clínic de Barcelona          CC-BY-NC
# 1      ISIC_0053454  Hospital Clínic de Barcelona          CC-BY-NC
# 3      ISIC_0053456  Hospital Clínic de Barcelona          CC-BY-NC
# 5      ISIC_0053458  Hospital Clínic de Barcelona          CC-BY-NC
# 6      ISIC_0053459  Hospital Clínic de Barcelona          CC-BY-NC
# ...             ...                           ...               ...
# 18938  ISIC_0073247  Hospital Clínic de Barcelona          CC-BY-NC
# 18939  ISIC_0073248  Hospital Clínic de Barcelona          CC-BY-NC
# 18940  ISIC_0073249  Hospital Clínic de Barcelona          CC-BY-NC
# 18941  ISIC_0073250  Hospital Clínic de Barcelona          CC-BY-NC
# 18945  ISIC_0073254  Hospital Clínic de Barcelona          CC-BY-NC
#
#        age_approx    anatom_site_1   anatom_site_2 anatom_site_general  \
# 0            60.0            Trunk  Anterior trunk      anterior torso
# ...

# %%
train_df.dx.value_counts()
# Out:
# dx
# nv       4214
# mel      3022
# bcc      2788
# bkl       976
# akiec     784
# vasc      108
# df        100
# Name: count, dtype: int64

# %%
test_df.dx.value_counts()
# Out:
# dx
# nv       1433
# mel       981
# bcc       888
# akiec     304
# bkl       292
# df         68
# vasc       43
# Name: count, dtype: int64
